# %%
import pandas as pd

# %% [markdown]
# # Muertes no Fetales

# %%
df2020 = pd.read_csv('nofetal2020.csv', sep=',', encoding='latin-1')
df2021 = pd.read_csv('nofetal2021.csv', sep=',', encoding='latin-1')
df2022 = pd.read_csv('nofetal2022.csv', sep=',', encoding='latin-1')
df2023 = pd.read_csv('nofetal2023.csv', sep=',', encoding='latin-1')
df2024 = pd.read_csv('nofetal2024.csv', sep=',', encoding='latin-1')

# %%
df2020.info()

# %%
df2021.info()

# %%
df2022.info()

# %%
df2023.info()

# %%
df2024.info()
